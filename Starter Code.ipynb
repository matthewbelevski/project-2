# %%
import geopandas
import pandas as pd

# %%
#pd.set_option('display.width', 1000)

# %%
url = "https://data.gov.au/geoserver/audit-2019-congestion-on-all-roads-during-2031-pm-peak/wfs?request=GetFeature&typeName=ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604&outputFormat=json"
df = geopandas.read_file(url)

# %%
df.head(20)
# Out:
#                                               id  \
# 0    ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604.1
# 1    ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604.2
# 2    ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604.3
# 3    ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604.4
# 4    ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604.5
# 5    ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604.6
# 6    ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604.7
# 7    ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604.8
# 8    ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604.9
# 9   ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604.10
# 10  ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604.11
# 11  ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604.12
# 12  ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604.13
# 13  ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604.14
# 14  ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604.15
# 15  ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604.16
# 16  ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604.17
# 17  ckan_cdd116c9_9cbb_4f35_a4b1_876029c2b604.18
# ...

# %%
df.to_csv("RoadCongestion.csv")

# %%
df.dtypes
# Out:
# id             object
# route          object
# direction      object
# segment        object
# speed           int64
# volume          int64
# vcr           float64
# vcr_cat        object
# geometry     geometry
# dtype: object

# %%
df.info(memory_usage='deep')
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 226227 entries, 0 to 226226
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         226227 non-null  object
#  1   route      35352 non-null   object
#  2   direction  35234 non-null   object
#  3   segment    35172 non-null   object
#  4   speed      226227 non-null  int64
#  5   volume     226227 non-null  int64
#  6   vcr        226227 non-null  float64
#  7   vcr_cat    226227 non-null  object
#  8   geometry   226227 non-null  geometry
# dtypes: float64(1), geometry(1), int64(2), object(5)
# memory usage: 64.4 MB

# %%
df["geometry"] = df["geometry"].astype(str)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-9-25714e43c09e> in <module>
# ----> 1 df["geometry"] = df["geometry"].astype(str)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
new = df["geometry"].str.split(expand = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.infer_dtype()
#
# TypeError: Cannot convert GeometryArray to numpy.ndarray
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-931368b4bb27> in <module>
# ----> 1 new = df["geometry"].str.split(expand = True)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
# ...

# %%
df1["long"] = new[1]
df1["lat"] = new[2]

# %%
df1['long'] = df1['long'].str.replace('(', '')
df1['lat'] = df1['lat'].str.replace(',', '')

# %%
df.to_csv("RoadCongestionClean.csv")

# %%
city_name1 = []
for index, row in df.iterrows():
    
    long = row["long"]
    lat = row["lat"]
    
    
    cities1 = citipy.nearest_city(lat, long)
    city_name.append(cities1.city_name)

df1["city"] = city_name1

# %%
url2 = "https://data.gov.au/geoserver/audit-2019-crowding-on-suburban-trains-during-2031-pm-peak/wfs?request=GetFeature&typeName=ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca&outputFormat=json"
df2 = geopandas.read_file(url2)

# %%
df2.head(20)
# Out:
#                                               id route direction segment  \
# 0    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.1  None      None    None
# 1    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.2  None      None    None
# 2    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.3  None      None    None
# 3    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.4  None      None    None
# 4    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.5  None      None    None
# 5    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.6  None      None    None
# 6    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.7  None      None    None
# 7    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.8  None      None    None
# 8    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.9  None      None    None
# 9   ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.10  None      None    None
# 10  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.11  None      None    None
# 11  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.12  None      None    None
# ...

# %%
#df2.sort_values("segment")
# Out:
#                                                   id  \
# 1988  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.1983
# 1941  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.1938
# 1463  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.1460
# 1467  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.1463
# 925    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.924
# ...                                              ...
# 1967  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.1963
# 1968  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.1964
# 2000  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.1997
# 2003  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.2003
# 2004  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.2004
#
#                                        route   direction  \
# 1988                                    None        None
# 1941         Sydney to Central Coast - Train  Southbound
# 1463                                    None        None
# 1467                                    None        None
# ...

# %%
df2.dtypes
# Out:
# id             object
# route          object
# direction      object
# segment        object
# volume          int64
# vcr           float64
# vcr_cat        object
# geometry     geometry
# dtype: object

# %%
df2["geometry"] = df2["geometry"].astype(str)

# %%
new = df2["geometry"].str.split(expand = True)

# %%
new
# Out:
#                  0             1            2           3            4     \
# 0     MULTILINESTRING  ((138.582751  -34.941576,  138.582918  -34.942599,
# 1     MULTILINESTRING  ((138.583058  -34.943405,  138.582918  -34.942599,
# 2     MULTILINESTRING  ((138.536645  -34.876212,  138.536411     -34.876,
# 3     MULTILINESTRING  ((138.529348  -34.870484,   138.52974  -34.870825,
# 4     MULTILINESTRING  ((138.597471  -34.966207,  138.597287  -34.966013,
# ...               ...           ...          ...         ...          ...
# 2033  MULTILINESTRING  ((151.004362  -33.817095,  151.004083   -33.81698,
# 2034  MULTILINESTRING  ((151.186293  -33.896685,  151.183457  -33.897555,
# 2035  MULTILINESTRING  ((150.956349  -33.801456,  150.955804  -33.800998,
# 2036  MULTILINESTRING  ((150.951564  -33.787398,  150.951468  -33.786957,
# 2037  MULTILINESTRING  ((150.935832  -33.774296,   150.93613  -33.774349,
#
#             5             6           7             8           9     ...  \
# ...

# %%
df2["long"] = new[1]
df2["lat"] = new[2]

# %%
df2['long'] = df2['long'].str.replace('(', '')

df2['lat'] = df2['lat'].str.replace(',', '')

# %%
df2.head()
# Out:
#                                             id route direction segment  \
# 0  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.1  None      None    None
# 1  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.2  None      None    None
# 2  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.3  None      None    None
# 3  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.4  None      None    None
# 4  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.5  None      None    None
#
#    volume  vcr vcr_cat                                           geometry  \
# 0    5000  0.7  Medium  MULTILINESTRING ((138.582751 -34.941576, 138.5...
# 1    2000  0.3     Low  MULTILINESTRING ((138.583058 -34.943405, 138.5...
# 2    2000  0.5     Low  MULTILINESTRING ((138.536645 -34.876212, 138.5...
# 3    1000  0.1     Low  MULTILINESTRING ((138.529348 -34.870484, 138.5...
# 4    1000  0.2     Low  MULTILINESTRING ((138.597471 -34.966207, 138.5...
#
#          long         lat
# 0  138.582751  -34.941576
# 1  138.583058  -34.943405
# ...

# %%
df2["city"] = ""

# %%
df2.head()
# Out:
#                                             id route direction segment  \
# 0  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.1  None      None    None
# 1  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.2  None      None    None
# 2  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.3  None      None    None
# 3  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.4  None      None    None
# 4  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.5  None      None    None
#
#    volume  vcr vcr_cat                                           geometry  \
# 0    5000  0.7  Medium  MULTILINESTRING ((138.582751 -34.941576, 138.5...
# 1    2000  0.3     Low  MULTILINESTRING ((138.583058 -34.943405, 138.5...
# 2    2000  0.5     Low  MULTILINESTRING ((138.536645 -34.876212, 138.5...
# 3    1000  0.1     Low  MULTILINESTRING ((138.529348 -34.870484, 138.5...
# 4    1000  0.2     Low  MULTILINESTRING ((138.597471 -34.966207, 138.5...
#
#          long         lat city
# 0  138.582751  -34.941576
# 1  138.583058  -34.943405
# ...

# %%
from citipy import citipy

# %%
df2["lat"] = df2["lat"].astype(float)
df2["long"] = df2["long"].astype(float)

# %%
df2.dtypes
# Out:
# id            object
# route         object
# direction     object
# segment       object
# volume         int64
# vcr          float64
# vcr_cat       object
# geometry      object
# long         float64
# lat          float64
# city          object
# dtype: object

# %%
city_name = []
for index, row in df2.iterrows():
    
    long = row["long"]
    lat = row["lat"]
    
    name = row["city"]
    
    cities = citipy.nearest_city(lat, long)
    city_name.append(cities.city_name)
    #df2 = df2.append(cities.city_name)

df2["city"] = city_name

# %%
len(city_name)
# Out:
# 2038

# %%
df2.head(20)
# Out:
#                                               id route direction segment  \
# 0    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.1  None      None    None
# 1    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.2  None      None    None
# 2    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.3  None      None    None
# 3    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.4  None      None    None
# 4    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.5  None      None    None
# 5    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.6  None      None    None
# 6    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.7  None      None    None
# 7    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.8  None      None    None
# 8    ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.9  None      None    None
# 9   ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.10  None      None    None
# 10  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.11  None      None    None
# 11  ckan_50a8f7ba_e2ab_4fda_8729_04b24430c3ca.12  None      None    None
# ...

# %%
df2.city.unique()
# Out:
# array(['adelaide', 'gawler', 'melbourne', 'cranbourne', 'healesville',
#        'craigieburn', 'sunbury', 'pakenham', 'somerville', 'melton',
#        'perth', 'kwinana', 'mandurah', 'sydney', 'brisbane', 'gympie',
#        'deception bay', 'buderim', 'nerang', 'gold coast', 'caboolture',
#        'morayfield', 'nambour', 'burpengary', 'victoria point',
#        'caloundra', 'gatton', 'wollongong', 'raymond terrace', 'bowral',
#        'moss vale', 'mittagong', 'kiama', 'muswellbrook', 'singleton',
#        'cessnock', 'newcastle', 'kurri kurri', 'lithgow'], dtype=object)

# %%
df2.to_csv("PTCrowding.csv")
df2.to_csv("PTCrowdingClean.csv")

# %%
df3 = pd.read_csv('weatherAUS.csv/weatherAUS.csv')

# %%
df3.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
location = df3["Location"]

# %%
# Out:
# 0         Albury
# 1         Albury
# 2         Albury
# 3         Albury
# 4         Albury
#            ...
# 145455     Uluru
# 145456     Uluru
# 145457     Uluru
# 145458     Uluru
# 145459     Uluru
# Name: Location, Length: 145460, dtype: object
